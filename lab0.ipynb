# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/PUS2024/blob/main/lab0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# make a plot here

# %%
import pylab as plt
import numpy as np
plt.plot(np.arange(10), np.random.randn(10) + np.arange(10) * 0.1)
plt.xlabel("x")
plt.ylabel("y");

# %% [markdown]
# figure 1. a plot of mostly random numbers
